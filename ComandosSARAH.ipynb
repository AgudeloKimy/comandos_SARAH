# %%
cd /home/auxiliar/BSM_Submodules/SPHENO
# Out:
# /home/auxiliar/BSM_Submodules/SPheno

# %%
# !rm -r Udark
# Out:
# rm: cannot remove 'Udark': No such file or directory

# %%
# !mkdir Udark

# %%
cd Udark
# Out:
# /home/auxiliar/BSM_Submodules/SPheno/Udark

# %%
# !cp -r /home/auxiliar/BSM_Submodules/SARAH/Output/Udark/EWSB/SPheno/* .

# %%
cd ..
# Out:
# /home/auxiliar/BSM_Submodules/SPheno

# %%
# !make Model=Udark
# Out:
# cd Udark ; make F90=gfortran version=400.00
# make[1]: Entering directory '/home/auxiliar/BSM_Submodules/SPheno/Udark'
# cd ../src ; make F90=gfortran
# make[2]: Entering directory '/home/auxiliar/BSM_Submodules/SPheno/src'
# gfortran -c -O -J../include -I../include  -DGENERATIONMIXING  -DONLYDOUBLE Control.F90
# ar -U -ruc ../lib/libSPheno.a Control.o
# rm -f Control.o
# gfortran -c -O -J../include -I../include Mathematics.f90
# ar -U -ruc ../lib/libSPheno.a Mathematics.o
# rm -f Mathematics.o
# gfortran -c -O -J../include -I../include  -DGENERATIONMIXING  -DONLYDOUBLE RGEs.F90
# RGEs.F90:100:0:
#
#   100 | # endif SEESAWIII
#       |
# ...
# RGEs.F90:15605:0:
#
# 15605 | #endif SEESAWIII
#       |
# ...
# RGEs.F90:20510:0:
#
# 20510 | #endif SEESAWIII
#       |
# ...
# ar -U -ruc ../lib/libSPheno.a RGEs.o
# rm -f RGEs.o
# gfortran -c -O -J../include -I../include MathematicsQP.f90
# ar -U -ruc ../lib/libSPheno.a MathematicsQP.o
# rm -f MathematicsQP.o
# ...

# %%
cd bin
# Out:
# /home/auxiliar/BSM_Submodules/SPheno/bin

# %%
# !./SPhenoUdark /home/auxiliar/BSM_Submodules/SPHENO/Udark/Input_Files/LesHouches.in.Udark
# Out:
#  Calculating branching ratios and decay widths
#  Calculating low energy constraints
#  Calculating unitarity constraints
#  Best submatrix:            1
#  Writing output files
#  Finished!

# %%
cd /home/auxiliar/BSM_Submodules/micromegas
# Out:
# /home/auxiliar/BSM_Submodules/micromegas

# %%
# !make
# Out:
# echo \#define micrO \"/home/auxiliar/BSM_Submodules/micromegas\"  > include/microPath.h
# make -C CalcHEP_src  MICROMEGAS=MICROMEGAS
# make[1]: Entering directory '/home/auxiliar/BSM_Submodules/micromegas/CalcHEP_src'
# ./getFlags
# MAKE= gmake
# CC=gcc by default
# UNAME=Linux ???
# numerical type Ok
# C compiler detected
# : shared liblary generation OK
# X11 OK
# Fortran compiler is detected
# gfortran OK
# FFLAGS OK
# ./sbin/setPath /home/auxiliar/BSM_Submodules/micromegas/CalcHEP_src
# chmod 755 mkWORKdir
# make -C c_source
# make[2]: Entering directory '/home/auxiliar/BSM_Submodules/micromegas/CalcHEP_src/c_source'
# make -C getmem
# make[3]: Entering directory '/home/auxiliar/BSM_Submodules/micromegas/CalcHEP_src/c_source/getmem'
# gcc -g -fsigned-char -std=gnu99 -fPIC -Iinclude -I../chep_crt/include   -c -o getmem.o getmem.c
# ar rv ../../lib/serv.a getmem.o
# ar: creating ../../lib/serv.a
# a - getmem.o
# ranlib ../../lib/serv.a
# ...

# %%
# !./newProject Udark
# Out:
# data.par
# lib/
# lib/Makefile
# lib/pmodel.h
# lib/pmodel.fh
# lib/model.c
# main.c
# main.cpp
# Makefile
# README
# work/
# work/Makefile
# work/so_generated/
# work/lanhep/
# work/lanhep/Makefile
# work/calchep.ini
# work/models/
# work/models/vars1.mdl
# work/models/lgrng1.mdl
# work/models/func1.mdl
# work/models/prtcls1.mdl
# work/models/extlib1.mdl
# work/calchep
# work/results/
# work/tmp/

# %%
cd Udark/work/models
# Out:
# /home/auxiliar/BSM_Submodules/micromegas/Udark/work/models

# %%
# !pwd
# Out:
# /home/auxiliar/BSM_Submodules/micromegas/Udark/work/models

# %%
# !cp -r /home/auxiliar/BSM_Submodules/SARAH/Output/Udark/EWSB/CHep/* .

# %%
cd ..
# Out:
# /home/auxiliar/BSM_Submodules/micromegas/Udark/work

# %%
cd ..
# Out:
# /home/auxiliar/BSM_Submodules/micromegas/Udark

# %%
cp -r /home/auxiliar/BSM_Submodules/SARAH/Output/Udark/EWSB/CHep/CalcOmega_MOv5.cpp .

# %%
cp -r /home/auxiliar/BSM_Submodules/SPHENO/bin/SPheno.spc.Udark .

# %%
# !make main=CalcOmega_MOv5.cpp
# Out:
# make -C work
# make[1]: Entering directory '/home/auxiliar/BSM_Submodules/micromegas/Udark/work'
# rm -f tmp/safe
# ../../CalcHEP_src/bin/s_calchep -blind "{[[{[[[[[[{}0"
# ../../CalcHEP_src/bin/make_VandP models 1
# gcc -g -fsigned-char -std=gnu99 -fPIC -I../../CalcHEP_src/include   -c -o VandP.o VandP.c
# ar rv work_aux.a VandP.o
# ar: creating work_aux.a
# a - VandP.o
# echo char \* WORK=\"`pwd`\"\; >  path.c
# gcc -g -fsigned-char -std=gnu99 -fPIC -I../../CalcHEP_src/include   -c -o path.o path.c
# ar rv work_aux.a path.o
# a - path.o
# ranlib work_aux.a
# rm -f VandP.o  path.o
# make[1]: Leaving directory '/home/auxiliar/BSM_Submodules/micromegas/Udark/work'
# make -C lib
# make[1]: Entering directory '/home/auxiliar/BSM_Submodules/micromegas/Udark/lib'
# gcc -g -fsigned-char -std=gnu99 -fPIC   -c -o model.o model.c
# ar rv aLib.a model.o
# ar: creating aLib.a
# a - model.o
# ranlib aLib.a
# rm -f model.o
# ...

# %%
# !./CalcOmega_MOv5
# Out:
# Masses of odd sector Particles:
# ~Xi      : MXi     = 636.396 ||
# PROCESS: ~Xi,~Xi->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# Processes of this type are absent
# PROCESS: ~Xi,~xi->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# PROCESS: h2->2*x
# PROCESS: h2 -> h1,h1,h1
# PROCESS: h2 -> h1,Z,Z
# PROCESS: h2 -> h1,Wm,Wp
# PROCESS: h2 -> Z,Wm,Wp
# PROCESS: h2 -> Zp,Wm,Wp
# PROCESS: h2 -> h1,d1,D1
# PROCESS: h2 -> Z,d1,D1
# PROCESS: h2 -> Zp,d1,D1
# PROCESS: h2 -> h1,D1,d2
# PROCESS: h2 -> Z,D1,d2
# PROCESS: h2 -> Zp,D1,d2
# PROCESS: h2 -> h1,d1,D2
# PROCESS: h2 -> Z,d1,D2
# PROCESS: h2 -> Zp,d1,D2
# PROCESS: h2 -> h1,d2,D2
# PROCESS: h2 -> Z,d2,D2
# PROCESS: h2 -> Zp,d2,D2
# PROCESS: h2 -> h1,D1,d3
# PROCESS: h2 -> Z,D1,d3
# PROCESS: h2 -> Zp,D1,d3
# PROCESS: h2 -> h1,D2,d3
# PROCESS: h2 -> Z,D2,d3
# PROCESS: h2 -> Zp,D2,d3
# PROCESS: h2 -> h1,d1,D3
# ...
